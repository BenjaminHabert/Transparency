# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['savefig.dpi'] = 150
from modules import transparency
import ipywidgets
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Nombre d'années avant condamnation en fonction de plusieurs critères

# %%
transparency.make_interactive_duree()

# %% [markdown]
# # Nombre d'affaires en fonction de plusieurs critères

# %%
transparency.make_interactive_nombre()

# %% [markdown]
# # Comparer la co-occurrence de différentes informations

# %%
transparency.make_interactive_heatmap()

# %% [markdown]
# # Montant de l'amende et durée avant condamnation

# %%
transparency.create_scatter_amande()
# Out:
# <div id="90447339-439e-4166-be23-53b89d0c003d" style="height: 700px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("90447339-439e-4166-be23-53b89d0c003d", [{"y": ["Premi\u00e8re instance", "Cour d'Appel", "Premi\u00e8re instance", "Cour d'Appel", "Premi\u00e8re instance", "Premi\u00e8re instance", "Cour d'Appel", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Cour d'Appel", "Cour d'Appel", "Premi\u00e8re instance", "Premi\u00e8re instance", "Cour d'Appel", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance", "Premi\u00e8re instance"
# ...

# %% [markdown]
# # Montant du préjudice

# %%
transparency.make_interactive_montant()
